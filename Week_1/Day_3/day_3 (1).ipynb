# %%
def sum_high(nums, k):
    maxlen = 0

    for i in range(len(nums)):
        current_sum = 0

        for j in range(i, len(nums)):
            current_sum += nums[j]

            if current_sum <= k:
                # Calculate the number of elements in the current window
                current_length = j - i + 1
                maxlen = max(current_length, maxlen)
            else:
                break

    return maxlen

nums = [1, 2, 3, 46, 8, 75, 4]
print(sum_high(nums, 14))  # Output: 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 20
#      17     return maxlen
#      19 nums = [1, 2, 3, 46, 8, 75, 4]
# ---> 20 print(sum_high(nums, 14))
#
# Cell In[21], line 13, in sum_high(nums, k)
#      10 if current_sum <= k:
#      11     # Calculate the number of elements in the current window
#      12     current_length = j - i + 1
# ---> 13     maxlen = max(current_length, maxlen)
#      14 else:
#      15     break
#
# Cell In[9], line 4, in max(nums, k)
#       1 def max(nums,k):
#       3     maxlen=0
# ----> 4     for i in range(len(nums)):
#       5         sum=0
#       6         for j in range(i,len(nums)):
#
# TypeError: object of type 'int' has no len()

# %%
def move_zero(nums):
    p=[]
    q=[]
    for  i in range(len(nums)):
        if(nums[i]==0):
            p.append(nums[i])
        else:
            q.append(nums[i])

    return(q+p)       

            
print(move_zero([0,1,0,3,12]))
print(move_zero([0]))
# Out:
# [1, 3, 12, 0, 0]
# [0]

# %%
class Solution:
    def moveZeroes(self, nums: List[int]) -> None:
        slow = 0

        for fast in range(len(nums)):
            if nums[fast] != 0:
                nums[slow], nums[fast] = nums[fast], nums[slow]
                slow += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 class Solution:
#       2     def moveZeroes(self, nums: List[int]) -> None:
#       3         slow = 0
#
# Cell In[41], line 2, in Solution()
#       1 class Solution:
# ----> 2     def moveZeroes(self, nums: List[int]) -> None:
#       3         slow = 0
#       5         for fast in range(len(nums)):
#
# NameError: name 'List' is not defined

# %%
from typing import List

class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:

        n = len(nums)
        result = [0] * n

        left = 0
        right = n - 1
        pos = n - 1

        while left <= right:

            left_square = nums[left] * nums[left]
            right_square = nums[right] * nums[right]

            if left_square > right_square:
                result[pos] = left_square
                left += 1
            else:
                result[pos] = right_square
                right -= 1

            pos -= 1

        return result
