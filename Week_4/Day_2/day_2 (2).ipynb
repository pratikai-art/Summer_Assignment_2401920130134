# %%
class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None

root=TreeNode(50)

root.left=TreeNode(40)
root.right=TreeNode(60)


root.left.left=TreeNode(30)
root.left.right=TreeNode(20)

root.right.left=TreeNode(10)
root.right.right=TreeNode(5)

def inorderTraversal(root):
    ans=[]
    def helpr(node):
        if node is None:
            
            return
        helpr(node.left) 
        ans.append(node.val)
        helpr(node.right)
    helpr(root)
    return ans   
    
    

    
print(inorderTraversal(root) )
# Out:
# [30, 40, 20, 50, 10, 60, 5]

# %%
from collections import deque
class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None

root=TreeNode(50)

root.left=TreeNode(40)
root.right=TreeNode(60)


root.left.left=TreeNode(30)
root.left.right=TreeNode(20)

root.right.left=TreeNode(10)
root.right.right=TreeNode(5)


def levelorder(root):
    if not root:
        return[]

    result=[]
    q=deque([root])

    while q:
        level=[]
        size=len(q)
        for _ in range(size):
            node=q.popleft()
            level.append(node.val)

            if node.left:
                q.append(node.left)

            if node.right:
                q.append(node.right)

        result.append(level)
    return result   
        
        
print(levelorder(root))
# Out:
# [[50], [40, 60], [30, 20, 10, 5]]

# %%
from collections import deque
class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None

root=TreeNode(50)

root.left=TreeNode(40)
root.right=TreeNode(60)


root.left.left=TreeNode(30)
root.left.right=TreeNode(20)

root.right.left=TreeNode(10)
root.right.right=TreeNode(5)

def levelorder(root):
    if not root:
        return[]

    result=[]
    q=deque([root])

    left_to_right=True    #here we are using the flag to check the left or right

    while q:
        
        level=[]
        size=len(q)
        for _ in range(size):
            node=q.popleft()
           
            level.append(node.val)
            
            

            if node.left:
                q.append(node.left)

            if node.right:
                q.append(node.right)
            
            
        if not left_to_right:
            level.reverse()
        result.append(level)

        left_to_right= not left_to_right   # turn the variable to false again
        
    return result   
        
        
print(levelorder(root))
# Out:
# [[50], [60, 40], [30, 20, 10, 5]]
